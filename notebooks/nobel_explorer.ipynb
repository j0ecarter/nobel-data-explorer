# %% [markdown]
# # Nobel Prize data explorer
#
# A compact walkthrough using the bundled sample dataset.

# %%
import sys
from pathlib import Path

# notebook sits one folder down
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project_root))
from analysis import (
    category_counts,
    decade_counts,
    gender_percentages,
    load_data,
    make_charts,
)

# %%
data = load_data(project_root / 'data' / 'nobel_sample.csv')
data.head()

# %%
category_counts(data), gender_percentages(data), decade_counts(data)

# %%
make_charts(data, project_root / 'figures')
